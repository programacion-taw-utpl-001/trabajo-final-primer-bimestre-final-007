# %%
import pandas as pd

# %% [markdown]
# Importamos la libreria Panda

# %%
df = pd.read_csv(r"Datos/divorcios.csv", sep=';',encoding="cp1252")

# %% [markdown]
# Realizamos la Respectiva Carga del archiv Csv

# %%
df.columns
# Out:
# Index(['ofi_insc', 'prov_insc', 'cant_insc', 'parr_insc', 'anio_insc',
#        'mes_insc', 'dia_insc', 'fecha_insc', 'anio_div', 'mes_div', 'dia_div',
#        'fecha_div', 'anio_mat', 'mes_mat', 'dia_mat', 'fecha_mat', 'mcapbie',
#        'dur_mat', 'cau_div', 'nac_hom', 'cod_paish', 'anio_nach', 'mes_nach',
#        'dia_nach', 'fecha_nach', 'edad_hom', 'hijos_hom', 'p_etnica_hom',
#        'sabe_leerh', 'niv_insth', 'prov_habh', 'cant_habh', 'parr_habh',
#        'area_hom', 'nac_muj', 'cod_paism', 'anio_nacm', 'mes_nacm', 'dia_nacm',
#        'fecha_nacm', 'edad_muj', 'hijos_muj', 'p_etnica_muj', 'sabe_leerm',
#        'niv_instm', 'prov_habm', 'cant_habm', 'parr_habm', 'area_muj'],
#       dtype='object')

# %% [markdown]
# Mostramos las columnas del archivo

# %%
df
# Out:
#        ofi_insc                       prov_insc      cant_insc  \
# 0             1                           Azuay         Cuenca
# 1             1                           Azuay         Cuenca
# 2             1                       Pichincha          Quito
# 3             1                         Bolivar       Guaranda
# 4             1                       Pichincha          Quito
# 5             1                       Pichincha          Quito
# 6             1                        Imbabura         Ibarra
# 7             1                            Loja           Loja
# 8             1                           Azuay         Cuenca
# 9             1                           Azuay         Cuenca
# 10            1                       Pichincha          Quito
# 11            1                           Azuay         Cuenca
# 12            1                           Azuay         Cuenca
# 13            1                           Azuay         Cuenca
# ...

# %% [markdown]
# Mostramos todos los datos del Archivo

# %%
data_filter = df[df['cant_insc'] == "Loja"]

# %% [markdown]
# Creamos un filtro del archivo lo cual nos permitira obtener solo datos de la provincia de Loja

# %%
data_filter
# Out:
#        ofi_insc prov_insc cant_insc  \
# 7             1      Loja      Loja
# 25            1      Loja      Loja
# 77            1      Loja      Loja
# 209           1      Loja      Loja
# 504           1      Loja      Loja
# 993           1      Loja      Loja
# 1162          1      Loja      Loja
# 1691          1      Loja      Loja
# 1741          1      Loja      Loja
# 2128          1      Loja      Loja
# 4210          1      Loja      Loja
# 4246          1      Loja      Loja
# 4836          1      Loja      Loja
# 4873          1      Loja      Loja
# 5208          1      Loja      Loja
# 5220          1      Loja      Loja
# 5228          1      Loja      Loja
# 5259          1      Loja      Loja
# 5349          1      Loja      Loja
# 5389          1      Loja      Loja
# 5572          1      Loja      Loja
# 5857          1      Loja      Loja
# 5895          1      Loja      Loja
# 5930          1      Loja      Loja
# 5960          1      Loja      Loja
# ...

# %% [markdown]
# Mostramos los datos Filtrados de la provincia de Loja

# %%
data_filter.to_csv('Datos/Loja.csv',sep=';',index=False)

# %% [markdown]
# Finalmente Generamos un Archivo Csv con los Datos Filtrados
